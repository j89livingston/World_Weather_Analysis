# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime
import requests
import time
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 737

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | qaanaaq
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | ranghulu
# Processing Record 4 of Set 1 | tura
# Processing Record 5 of Set 1 | wewak
# Processing Record 6 of Set 1 | tuatapere
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | jambi
# Processing Record 9 of Set 1 | dongsheng
# Processing Record 10 of Set 1 | ponta do sol
# Processing Record 11 of Set 1 | kodiak
# Processing Record 12 of Set 1 | hambantota
# Processing Record 13 of Set 1 | ancud
# Processing Record 14 of Set 1 | gandiaye
# Processing Record 15 of Set 1 | camacha
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | porto santo
# Processing Record 18 of Set 1 | kokstad
# Processing Record 19 of Set 1 | saint-philippe
# Processing Record 20 of Set 1 | soyo
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | san quintin
# Processing Record 26 of Set 1 | port lincoln
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | churapcha
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | kemin
# Processing Record 31 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | eskasem
# City not found. Skipping...
# Processing Record 34 of Set 1 | tasiilaq
# Processing Record 35 of Set 1 | del rio
# Processing Record 36 of Set 1 | nikolskoye
# Processing Record 37 of Set 1 | krasnoselkup
# Processing Record 38 of Set 1 | cap malheureux
# Processing Record 39 of Set 1 | tiksi
# Processing Record 40 of Set 1 | te anau
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 1 | pevek
# Processing Record 44 of Set 1 | ambulu
# Processing Record 45 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 1 | macapa
# Processing Record 47 of Set 1 | gediz
# Processing Record 48 of Set 1 | kapaa
# Processing Record 49 of Set 1 | upernavik
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | khatanga
# Processing Record 2 of Set 2 | rio grande
# Processing Record 3 of Set 2 | russell
# Processing Record 4 of Set 2 | georgetown
# Processing Record 5 of Set 2 | cayenne
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | aksu
# Processing Record 8 of Set 2 | tuktoyaktuk
# Processing Record 9 of Set 2 | castro
# Processing Record 10 of Set 2 | cidreira
# Processing Record 11 of Set 2 | palmer
# Processing Record 12 of Set 2 | thompson
# Processing Record 13 of Set 2 | avarua
# Processing Record 14 of Set 2 | yellowknife
# Processing Record 15 of Set 2 | chiredzi
# Processing Record 16 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 2 | ostrovnoy
# Processing Record 18 of Set 2 | shingu
# Processing Record 19 of Set 2 | rapid valley
# Processing Record 20 of Set 2 | vardo
# Processing Record 21 of Set 2 | mahebourg
# Processing Record 22 of Set 2 | port blair
# Processing Record 23 of Set 2 | mizpe ramon
# City not found. Skipping...
# Processing Record 24 of Set 2 | longyearbyen
# Processing Record 25 of Set 2 | mataura
# Processing Record 26 of Set 2 | norman wells
# Processing Record 27 of Set 2 | guarapari
# Processing Record 28 of Set 2 | kungurtug
# Processing Record 29 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 2 | clyde river
# Processing Record 31 of Set 2 | cravo norte
# Processing Record 32 of Set 2 | trat
# Processing Record 33 of Set 2 | jiuquan
# Processing Record 34 of Set 2 | yumen
# Processing Record 35 of Set 2 | indramayu
# Processing Record 36 of Set 2 | airai
# Processing Record 37 of Set 2 | atuona
# Processing Record 38 of Set 2 | hilo
# Processing Record 39 of Set 2 | tianpeng
# Processing Record 40 of Set 2 | kalmunai
# Processing Record 41 of Set 2 | plyussa
# Processing Record 42 of Set 2 | ravar
# Processing Record 43 of Set 2 | taoudenni
# Processing Record 44 of Set 2 | belaya gora
# Processing Record 45 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 2 | kimbe
# Processing Record 47 of Set 2 | coquimbo
# Processing Record 48 of Set 2 | nanortalik
# Processing Record 49 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 50 of Set 2 | naryan-mar
# Processing Record 1 of Set 3 | tra vinh
# Processing Record 2 of Set 3 | bredasdorp
# Processing Record 3 of Set 3 | vostok
# Processing Record 4 of Set 3 | carutapera
# Processing Record 5 of Set 3 | porto walter
# Processing Record 6 of Set 3 | faya
# Processing Record 7 of Set 3 | hermanus
# Processing Record 8 of Set 3 | olinda
# Processing Record 9 of Set 3 | husavik
# Processing Record 10 of Set 3 | karratha
# Processing Record 11 of Set 3 | saskylakh
# Processing Record 12 of Set 3 | valle hermoso
# Processing Record 13 of Set 3 | cherskiy
# Processing Record 14 of Set 3 | maceio
# Processing Record 15 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 3 | mar del plata
# Processing Record 17 of Set 3 | ginda
# Processing Record 18 of Set 3 | ixtapa
# Processing Record 19 of Set 3 | natitingou
# Processing Record 20 of Set 3 | carnarvon
# Processing Record 21 of Set 3 | new norfolk
# Processing Record 22 of Set 3 | suoyarvi
# Processing Record 23 of Set 3 | vila
# Processing Record 24 of Set 3 | kedrovyy
# Processing Record 25 of Set 3 | cabo san lucas
# Processing Record 26 of Set 3 | alice springs
# Processing Record 27 of Set 3 | lorengau
# Processing Record 28 of Set 3 | bathsheba
# Processing Record 29 of Set 3 | yueyang
# Processing Record 30 of Set 3 | ribeira grande
# Processing Record 31 of Set 3 | mitchell
# Processing Record 32 of Set 3 | barrow
# Processing Record 33 of Set 3 | codrington
# Processing Record 34 of Set 3 | cartersville
# Processing Record 35 of Set 3 | saldanha
# Processing Record 36 of Set 3 | santiago del estero
# Processing Record 37 of Set 3 | sidvokodvo
# Processing Record 38 of Set 3 | beringovskiy
# Processing Record 39 of Set 3 | laguna
# Processing Record 40 of Set 3 | leningradskiy
# Processing Record 41 of Set 3 | olafsvik
# Processing Record 42 of Set 3 | lebu
# Processing Record 43 of Set 3 | rocha
# Processing Record 44 of Set 3 | komsomolskiy
# Processing Record 45 of Set 3 | nokaneng
# Processing Record 46 of Set 3 | bengkulu
# Processing Record 47 of Set 3 | hirara
# Processing Record 48 of Set 3 | ullapool
# Processing Record 49 of Set 3 | okhotsk
# Processing Record 50 of Set 3 | gaur
# Processing Record 1 of Set 4 | roros
# Processing Record 2 of Set 4 | magnitka
# Processing Record 3 of Set 4 | hlukhiv
# Processing Record 4 of Set 4 | fortuna
# Processing Record 5 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 4 | woodburn
# Processing Record 7 of Set 4 | puerto ayora
# Processing Record 8 of Set 4 | bethel
# Processing Record 9 of Set 4 | luderitz
# Processing Record 10 of Set 4 | beidao
# Processing Record 11 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 4 | talnakh
# Processing Record 13 of Set 4 | bima
# Processing Record 14 of Set 4 | altus
# Processing Record 15 of Set 4 | yerbogachen
# Processing Record 16 of Set 4 | thinadhoo
# Processing Record 17 of Set 4 | longhua
# Processing Record 18 of Set 4 | tinskoy
# Processing Record 19 of Set 4 | guerrero negro
# Processing Record 20 of Set 4 | dicabisagan
# Processing Record 21 of Set 4 | shuangcheng
# Processing Record 22 of Set 4 | ye
# City not found. Skipping...
# Processing Record 23 of Set 4 | havelock
# Processing Record 24 of Set 4 | nova londrina
# Processing Record 25 of Set 4 | quatre cocos
# Processing Record 26 of Set 4 | addi ugri
# City not found. Skipping...
# Processing Record 27 of Set 4 | abonnema
# Processing Record 28 of Set 4 | kingisepp
# Processing Record 29 of Set 4 | tongliao
# Processing Record 30 of Set 4 | pisco
# Processing Record 31 of Set 4 | windsor
# Processing Record 32 of Set 4 | malakal
# Processing Record 33 of Set 4 | safaga
# Processing Record 34 of Set 4 | tual
# Processing Record 35 of Set 4 | lensk
# Processing Record 36 of Set 4 | kingston
# Processing Record 37 of Set 4 | chuy
# Processing Record 38 of Set 4 | doka
# Processing Record 39 of Set 4 | lagoa
# Processing Record 40 of Set 4 | severo-kurilsk
# Processing Record 41 of Set 4 | tigil
# Processing Record 42 of Set 4 | vao
# Processing Record 43 of Set 4 | east london
# Processing Record 44 of Set 4 | cacapava do sul
# Processing Record 45 of Set 4 | caravelas
# Processing Record 46 of Set 4 | bilma
# Processing Record 47 of Set 4 | ternate
# Processing Record 48 of Set 4 | basco
# Processing Record 49 of Set 4 | alofi
# Processing Record 50 of Set 4 | saint-ambroise
# Processing Record 1 of Set 5 | north little rock
# Processing Record 2 of Set 5 | emirdag
# Processing Record 3 of Set 5 | college
# Processing Record 4 of Set 5 | srandakan
# Processing Record 5 of Set 5 | lucapa
# Processing Record 6 of Set 5 | mansehra
# Processing Record 7 of Set 5 | port hardy
# Processing Record 8 of Set 5 | naliya
# Processing Record 9 of Set 5 | havoysund
# Processing Record 10 of Set 5 | kaitangata
# Processing Record 11 of Set 5 | dalbandin
# Processing Record 12 of Set 5 | anadyr
# Processing Record 13 of Set 5 | tabou
# Processing Record 14 of Set 5 | makakilo city
# Processing Record 15 of Set 5 | tongzi
# Processing Record 16 of Set 5 | kenai
# Processing Record 17 of Set 5 | kavieng
# Processing Record 18 of Set 5 | barguzin
# Processing Record 19 of Set 5 | hervey bay
# Processing Record 20 of Set 5 | naze
# Processing Record 21 of Set 5 | sao joao da barra
# Processing Record 22 of Set 5 | carauari
# Processing Record 23 of Set 5 | wanning
# Processing Record 24 of Set 5 | muisne
# Processing Record 25 of Set 5 | kadaya
# Processing Record 26 of Set 5 | beloha
# Processing Record 27 of Set 5 | ushtobe
# Processing Record 28 of Set 5 | yulara
# Processing Record 29 of Set 5 | arlit
# Processing Record 30 of Set 5 | narsaq
# Processing Record 31 of Set 5 | hereford
# Processing Record 32 of Set 5 | katsuura
# Processing Record 33 of Set 5 | belyye berega
# Processing Record 34 of Set 5 | constitucion
# Processing Record 35 of Set 5 | umea
# Processing Record 36 of Set 5 | klaksvik
# Processing Record 37 of Set 5 | dawei
# Processing Record 38 of Set 5 | margate
# Processing Record 39 of Set 5 | bulawayo
# Processing Record 40 of Set 5 | ueda
# Processing Record 41 of Set 5 | ilulissat
# Processing Record 42 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 43 of Set 5 | nouadhibou
# Processing Record 44 of Set 5 | tondano
# Processing Record 45 of Set 5 | kannauj
# Processing Record 46 of Set 5 | bolgatanga
# Processing Record 47 of Set 5 | rexburg
# Processing Record 48 of Set 5 | nome
# Processing Record 49 of Set 5 | bull savanna
# Processing Record 50 of Set 5 | victoria
# Processing Record 1 of Set 6 | svetlogorsk
# Processing Record 2 of Set 6 | praia da vitoria
# Processing Record 3 of Set 6 | miraflores
# Processing Record 4 of Set 6 | dingle
# Processing Record 5 of Set 6 | seoul
# Processing Record 6 of Set 6 | sechura
# Processing Record 7 of Set 6 | acapulco
# Processing Record 8 of Set 6 | chokurdakh
# Processing Record 9 of Set 6 | gambela
# Processing Record 10 of Set 6 | port moresby
# Processing Record 11 of Set 6 | vanimo
# Processing Record 12 of Set 6 | ampanihy
# Processing Record 13 of Set 6 | tutoia
# Processing Record 14 of Set 6 | bohicon
# Processing Record 15 of Set 6 | atambua
# Processing Record 16 of Set 6 | arona
# Processing Record 17 of Set 6 | mareeba
# Processing Record 18 of Set 6 | tezu
# Processing Record 19 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 20 of Set 6 | magistralnyy
# Processing Record 21 of Set 6 | kahului
# Processing Record 22 of Set 6 | muros
# Processing Record 23 of Set 6 | byron bay
# Processing Record 24 of Set 6 | sorong
# Processing Record 25 of Set 6 | clarence town
# Processing Record 26 of Set 6 | simao
# Processing Record 27 of Set 6 | vestmannaeyjar
# Processing Record 28 of Set 6 | uray
# Processing Record 29 of Set 6 | buchanan
# Processing Record 30 of Set 6 | san patricio
# Processing Record 31 of Set 6 | atascadero
# Processing Record 32 of Set 6 | la palma
# Processing Record 33 of Set 6 | faanui
# Processing Record 34 of Set 6 | okha
# Processing Record 35 of Set 6 | cairns
# Processing Record 36 of Set 6 | zheleznodorozhnyy
# Processing Record 37 of Set 6 | tocopilla
# Processing Record 38 of Set 6 | morgan city
# Processing Record 39 of Set 6 | novobirilyussy
# Processing Record 40 of Set 6 | paragominas
# Processing Record 41 of Set 6 | chifeng
# Processing Record 42 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 6 | wanaka
# Processing Record 44 of Set 6 | khani
# Processing Record 45 of Set 6 | ayan
# Processing Record 46 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 6 | kashan
# Processing Record 48 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 6 | san benito
# Processing Record 50 of Set 6 | valdemarpils
# Processing Record 1 of Set 7 | eten
# Processing Record 2 of Set 7 | staunton
# Processing Record 3 of Set 7 | chimoio
# Processing Record 4 of Set 7 | dikson
# Processing Record 5 of Set 7 | lodja
# Processing Record 6 of Set 7 | takaka
# Processing Record 7 of Set 7 | oranjemund
# Processing Record 8 of Set 7 | itoman
# Processing Record 9 of Set 7 | porteirinha
# Processing Record 10 of Set 7 | port elizabeth
# Processing Record 11 of Set 7 | nema
# Processing Record 12 of Set 7 | denpasar
# Processing Record 13 of Set 7 | zabaykalsk
# Processing Record 14 of Set 7 | kochubey
# Processing Record 15 of Set 7 | prata
# Processing Record 16 of Set 7 | port hedland
# Processing Record 17 of Set 7 | palmaner
# Processing Record 18 of Set 7 | xichang
# Processing Record 19 of Set 7 | fria
# Processing Record 20 of Set 7 | torbay
# Processing Record 21 of Set 7 | novo selo
# Processing Record 22 of Set 7 | hualmay
# Processing Record 23 of Set 7 | omsukchan
# Processing Record 24 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 7 | dakar
# Processing Record 26 of Set 7 | hithadhoo
# Processing Record 27 of Set 7 | mehran
# Processing Record 28 of Set 7 | pangnirtung
# Processing Record 29 of Set 7 | cockburn town
# Processing Record 30 of Set 7 | nizhneudinsk
# Processing Record 31 of Set 7 | ako
# Processing Record 32 of Set 7 | mantua
# Processing Record 33 of Set 7 | kamojima
# Processing Record 34 of Set 7 | dubrovnik
# Processing Record 35 of Set 7 | kavaratti
# Processing Record 36 of Set 7 | arraial do cabo
# Processing Record 37 of Set 7 | hobyo
# Processing Record 38 of Set 7 | hamilton
# Processing Record 39 of Set 7 | isla mujeres
# Processing Record 40 of Set 7 | port hawkesbury
# Processing Record 41 of Set 7 | hovd
# Processing Record 42 of Set 7 | aklavik
# Processing Record 43 of Set 7 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 44 of Set 7 | pokhara
# Processing Record 45 of Set 7 | cam ranh
# Processing Record 46 of Set 7 | isangel
# Processing Record 47 of Set 7 | meulaboh
# Processing Record 48 of Set 7 | labytnangi
# Processing Record 49 of Set 7 | kyshtovka
# Processing Record 50 of Set 7 | kytlym
# City not found. Skipping...
# Processing Record 1 of Set 8 | nelson bay
# Processing Record 2 of Set 8 | tucuman
# Processing Record 3 of Set 8 | vilhena
# Processing Record 4 of Set 8 | ulladulla
# Processing Record 5 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 6 of Set 8 | catio
# Processing Record 7 of Set 8 | mangai
# Processing Record 8 of Set 8 | nantucket
# Processing Record 9 of Set 8 | sinnamary
# Processing Record 10 of Set 8 | opuwo
# Processing Record 11 of Set 8 | sai buri
# Processing Record 12 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 8 | honningsvag
# Processing Record 14 of Set 8 | hami
# Processing Record 15 of Set 8 | requena
# Processing Record 16 of Set 8 | guaraniacu
# Processing Record 17 of Set 8 | port-gentil
# Processing Record 18 of Set 8 | sitka
# Processing Record 19 of Set 8 | manta
# Processing Record 20 of Set 8 | valparaiso
# Processing Record 21 of Set 8 | la brea
# Processing Record 22 of Set 8 | marsh harbour
# Processing Record 23 of Set 8 | mangan
# Processing Record 24 of Set 8 | izhma
# Processing Record 25 of Set 8 | trelew
# Processing Record 26 of Set 8 | lai
# Processing Record 27 of Set 8 | remontnoye
# Processing Record 28 of Set 8 | robe
# Processing Record 29 of Set 8 | adolfo lopez mateos
# Processing Record 30 of Set 8 | zharkent
# Processing Record 31 of Set 8 | harper
# Processing Record 32 of Set 8 | noumea
# Processing Record 33 of Set 8 | teacapan
# Processing Record 34 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 35 of Set 8 | roura
# Processing Record 36 of Set 8 | tessalit
# Processing Record 37 of Set 8 | kantunilkin
# Processing Record 38 of Set 8 | watsa
# Processing Record 39 of Set 8 | deputatskiy
# Processing Record 40 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 41 of Set 8 | villa oliva
# City not found. Skipping...
# Processing Record 42 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 8 | staryy nadym
# Processing Record 44 of Set 8 | ondjiva
# Processing Record 45 of Set 8 | coos bay
# Processing Record 46 of Set 8 | mezhdurechensk
# Processing Record 47 of Set 8 | saint-joseph
# Processing Record 48 of Set 8 | srednekolymsk
# Processing Record 49 of Set 8 | robertsport
# Processing Record 50 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 1 of Set 9 | fallon
# Processing Record 2 of Set 9 | sisimiut
# Processing Record 3 of Set 9 | san cristobal
# Processing Record 4 of Set 9 | kruisfontein
# Processing Record 5 of Set 9 | pskov
# Processing Record 6 of Set 9 | contamana
# Processing Record 7 of Set 9 | saint george
# Processing Record 8 of Set 9 | nemuro
# Processing Record 9 of Set 9 | morlaix
# Processing Record 10 of Set 9 | kamenka
# Processing Record 11 of Set 9 | yar-sale
# Processing Record 12 of Set 9 | menongue
# Processing Record 13 of Set 9 | quisqueya
# Processing Record 14 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 9 | souillac
# Processing Record 16 of Set 9 | nortelandia
# Processing Record 17 of Set 9 | ingham
# Processing Record 18 of Set 9 | shimanovsk
# Processing Record 19 of Set 9 | plettenberg bay
# Processing Record 20 of Set 9 | cozumel
# Processing Record 21 of Set 9 | pitimbu
# Processing Record 22 of Set 9 | usta muhammad
# Processing Record 23 of Set 9 | otradnoye
# Processing Record 24 of Set 9 | roma
# Processing Record 25 of Set 9 | solnechnyy
# Processing Record 26 of Set 9 | sonoita
# Processing Record 27 of Set 9 | kodinsk
# Processing Record 28 of Set 9 | uwayl
# City not found. Skipping...
# Processing Record 29 of Set 9 | tilichiki
# Processing Record 30 of Set 9 | portland
# Processing Record 31 of Set 9 | udachnyy
# Processing Record 32 of Set 9 | conceicao do araguaia
# Processing Record 33 of Set 9 | fethiye
# Processing Record 34 of Set 9 | winnemucca
# Processing Record 35 of Set 9 | ostersund
# Processing Record 36 of Set 9 | ulaangom
# Processing Record 37 of Set 9 | walvis bay
# Processing Record 38 of Set 9 | santa lucia
# Processing Record 39 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 40 of Set 9 | bairiki
# Processing Record 41 of Set 9 | aksarka
# Processing Record 42 of Set 9 | phalodi
# Processing Record 43 of Set 9 | novochernorechenskiy
# Processing Record 44 of Set 9 | belmonte
# Processing Record 45 of Set 9 | chapais
# Processing Record 46 of Set 9 | jishou
# Processing Record 47 of Set 9 | kirovsk
# Processing Record 48 of Set 9 | erzin
# Processing Record 49 of Set 9 | maltahohe
# Processing Record 50 of Set 9 | provideniya
# Processing Record 1 of Set 10 | scarborough
# Processing Record 2 of Set 10 | ereymentau
# Processing Record 3 of Set 10 | esperance
# Processing Record 4 of Set 10 | broome
# Processing Record 5 of Set 10 | urengoy
# Processing Record 6 of Set 10 | namibe
# Processing Record 7 of Set 10 | znamenskoye
# Processing Record 8 of Set 10 | christchurch
# Processing Record 9 of Set 10 | brzeg dolny
# Processing Record 10 of Set 10 | gat
# Processing Record 11 of Set 10 | mbanza-ngungu
# Processing Record 12 of Set 10 | ukiah
# Processing Record 13 of Set 10 | vacaria
# Processing Record 14 of Set 10 | lidorikion
# City not found. Skipping...
# Processing Record 15 of Set 10 | geraldton
# Processing Record 16 of Set 10 | richards bay
# Processing Record 17 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 18 of Set 10 | harnosand
# Processing Record 19 of Set 10 | iqaluit
# Processing Record 20 of Set 10 | leshukonskoye
# Processing Record 21 of Set 10 | dryden
# Processing Record 22 of Set 10 | dhupgari
# Processing Record 23 of Set 10 | shu
# Processing Record 24 of Set 10 | puerto leguizamo
# Processing Record 25 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 10 | haimen
# Processing Record 27 of Set 10 | tiarei
# Processing Record 28 of Set 10 | nuuk
# Processing Record 29 of Set 10 | lubango
# Processing Record 30 of Set 10 | demirci
# Processing Record 31 of Set 10 | razdolnoye
# Processing Record 32 of Set 10 | lompoc
# Processing Record 33 of Set 10 | sept-iles
# Processing Record 34 of Set 10 | natchitoches
# Processing Record 35 of Set 10 | ahipara
# Processing Record 36 of Set 10 | cururupu
# Processing Record 37 of Set 10 | can tho
# Processing Record 38 of Set 10 | arya
# Processing Record 39 of Set 10 | peleduy
# Processing Record 40 of Set 10 | vila velha
# Processing Record 41 of Set 10 | kieta
# Processing Record 42 of Set 10 | hefei
# Processing Record 43 of Set 10 | weihe
# Processing Record 44 of Set 10 | vanavara
# Processing Record 45 of Set 10 | kargasok
# Processing Record 46 of Set 10 | porto-vecchio
# Processing Record 47 of Set 10 | bandarbeyla
# Processing Record 48 of Set 10 | charters towers
# Processing Record 49 of Set 10 | correntina
# Processing Record 50 of Set 10 | namtsy
# Processing Record 1 of Set 11 | saint-louis
# Processing Record 2 of Set 11 | itaituba
# Processing Record 3 of Set 11 | aljezur
# Processing Record 4 of Set 11 | mackay
# Processing Record 5 of Set 11 | luanda
# Processing Record 6 of Set 11 | poso
# Processing Record 7 of Set 11 | bani walid
# Processing Record 8 of Set 11 | devonport
# Processing Record 9 of Set 11 | muzquiz
# City not found. Skipping...
# Processing Record 10 of Set 11 | palencia
# Processing Record 11 of Set 11 | madera
# Processing Record 12 of Set 11 | freetown
# Processing Record 13 of Set 11 | mecca
# Processing Record 14 of Set 11 | progreso
# Processing Record 15 of Set 11 | butajira
# Processing Record 16 of Set 11 | bambous virieux
# Processing Record 17 of Set 11 | alpena
# Processing Record 18 of Set 11 | colomi
# Processing Record 19 of Set 11 | lerwick
# Processing Record 20 of Set 11 | helong
# Processing Record 21 of Set 11 | aranos
# Processing Record 22 of Set 11 | aleksandrov gay
# Processing Record 23 of Set 11 | lavrentiya
# Processing Record 24 of Set 11 | kyra
# Processing Record 25 of Set 11 | tecoanapa
# Processing Record 26 of Set 11 | lata
# Processing Record 27 of Set 11 | maragogi
# Processing Record 28 of Set 11 | mildura
# Processing Record 29 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 30 of Set 11 | sherbakul
# Processing Record 31 of Set 11 | voh
# Processing Record 32 of Set 11 | mangrol
# Processing Record 33 of Set 11 | salinas
# Processing Record 34 of Set 11 | refojos de basto
# Processing Record 35 of Set 11 | rawson
# Processing Record 36 of Set 11 | warragul
# Processing Record 37 of Set 11 | sao felix do xingu
# Processing Record 38 of Set 11 | fairbanks
# Processing Record 39 of Set 11 | espinosa
# Processing Record 40 of Set 11 | warmbad
# Processing Record 41 of Set 11 | terrak
# Processing Record 42 of Set 11 | killybegs
# Processing Record 43 of Set 11 | brewster
# Processing Record 44 of Set 11 | kirakira
# Processing Record 45 of Set 11 | shulin
# Processing Record 46 of Set 11 | waw
# Processing Record 47 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 11 | lasa
# Processing Record 49 of Set 11 | zhangye
# Processing Record 50 of Set 11 | mount isa
# Processing Record 1 of Set 12 | shenjiamen
# Processing Record 2 of Set 12 | mehamn
# Processing Record 3 of Set 12 | leninsk-kuznetskiy
# Processing Record 4 of Set 12 | long
# Processing Record 5 of Set 12 | kislyakovskaya
# Processing Record 6 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 12 | skierniewice
# Processing Record 8 of Set 12 | okandja
# City not found. Skipping...
# Processing Record 9 of Set 12 | zaozerne
# Processing Record 10 of Set 12 | cruden bay
# City not found. Skipping...
# Processing Record 11 of Set 12 | la ronge
# Processing Record 12 of Set 12 | oromocto
# Processing Record 13 of Set 12 | ibotirama
# Processing Record 14 of Set 12 | ankazoabo
# Processing Record 15 of Set 12 | champerico
# Processing Record 16 of Set 12 | hasaki
# Processing Record 17 of Set 12 | bouca
# Processing Record 18 of Set 12 | sikonge
# Processing Record 19 of Set 12 | kerman
# Processing Record 20 of Set 12 | sausar
# Processing Record 21 of Set 12 | oistins
# Processing Record 22 of Set 12 | todos santos
# Processing Record 23 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 24 of Set 12 | kangema
# Processing Record 25 of Set 12 | araouane
# Processing Record 26 of Set 12 | goderich
# Processing Record 27 of Set 12 | lovozero
# Processing Record 28 of Set 12 | seddon
# Processing Record 29 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 12 | half moon bay
# Processing Record 31 of Set 12 | whitehorse
# Processing Record 32 of Set 12 | marawi
# Processing Record 33 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 12 | hailar
# Processing Record 35 of Set 12 | le port
# Processing Record 36 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 37 of Set 12 | mahina
# Processing Record 38 of Set 12 | tadine
# Processing Record 39 of Set 12 | zhigansk
# Processing Record 40 of Set 12 | nishihara
# Processing Record 41 of Set 12 | torres
# Processing Record 42 of Set 12 | campbell river
# Processing Record 43 of Set 12 | taunggyi
# Processing Record 44 of Set 12 | benghazi
# Processing Record 45 of Set 12 | berlevag
# Processing Record 46 of Set 12 | mazara del vallo
# Processing Record 47 of Set 12 | sobolevo
# Processing Record 48 of Set 12 | sassandra
# Processing Record 49 of Set 12 | bafra
# Processing Record 50 of Set 12 | mombetsu
# Processing Record 1 of Set 13 | kardla
# Processing Record 2 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 3 of Set 13 | pingzhuang
# Processing Record 4 of Set 13 | edmundston
# Processing Record 5 of Set 13 | hofn
# Processing Record 6 of Set 13 | omboue
# Processing Record 7 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 8 of Set 13 | stokmarknes
# Processing Record 9 of Set 13 | prince rupert
# Processing Record 10 of Set 13 | namatanai
# Processing Record 11 of Set 13 | ahuimanu
# Processing Record 12 of Set 13 | north myrtle beach
# Processing Record 13 of Set 13 | san carlos de bariloche
# Processing Record 14 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 13 | mamakan
# Processing Record 16 of Set 13 | verkhnyaya inta
# Processing Record 17 of Set 13 | san andres
# Processing Record 18 of Set 13 | blagoyevo
# Processing Record 19 of Set 13 | kalanwali
# Processing Record 20 of Set 13 | evensk
# Processing Record 21 of Set 13 | coahuayana
# Processing Record 22 of Set 13 | grindavik
# Processing Record 23 of Set 13 | grafton
# Processing Record 24 of Set 13 | urusha
# Processing Record 25 of Set 13 | sola
# Processing Record 26 of Set 13 | dunedin
# Processing Record 27 of Set 13 | furstenwalde
# Processing Record 28 of Set 13 | chaozhou
# Processing Record 29 of Set 13 | bo
# City not found. Skipping...
# Processing Record 30 of Set 13 | boa vista
# Processing Record 31 of Set 13 | along
# Processing Record 32 of Set 13 | samarai
# Processing Record 33 of Set 13 | sinazongwe
# Processing Record 34 of Set 13 | sungaipenuh
# Processing Record 35 of Set 13 | lishui
# Processing Record 36 of Set 13 | chicama
# Processing Record 37 of Set 13 | huarmey
# Processing Record 38 of Set 13 | conde
# Processing Record 39 of Set 13 | saint-augustin
# Processing Record 40 of Set 13 | borama
# City not found. Skipping...
# Processing Record 41 of Set 13 | dunnville
# Processing Record 42 of Set 13 | williamsport
# Processing Record 43 of Set 13 | hay river
# Processing Record 44 of Set 13 | ossora
# Processing Record 45 of Set 13 | mianyang
# Processing Record 46 of Set 13 | zolotinka
# City not found. Skipping...
# Processing Record 47 of Set 13 | liverpool
# Processing Record 48 of Set 13 | phrai bung
# City not found. Skipping...
# Processing Record 49 of Set 13 | skibbereen
# Processing Record 50 of Set 13 | venice
# Processing Record 1 of Set 14 | songea
# Processing Record 2 of Set 14 | kuhdasht
# Processing Record 3 of Set 14 | rodrigues alves
# Processing Record 4 of Set 14 | yuanli
# Processing Record 5 of Set 14 | linqu
# Processing Record 6 of Set 14 | saryg-sep
# Processing Record 7 of Set 14 | zhangjiakou
# Processing Record 8 of Set 14 | neuquen
# Processing Record 9 of Set 14 | nioro
# Processing Record 10 of Set 14 | toulepleu
# City not found. Skipping...
# Processing Record 11 of Set 14 | banswada
# Processing Record 12 of Set 14 | jibuti
# Processing Record 13 of Set 14 | chute-aux-outardes
# Processing Record 14 of Set 14 | at-bashi
# Processing Record 15 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 14 | tafresh
# Processing Record 17 of Set 14 | carahue
# Processing Record 18 of Set 14 | tukrah
# Processing Record 19 of Set 14 | marzuq
# Processing Record 20 of Set 14 | mandawar
# Processing Record 21 of Set 14 | eureka
# Processing Record 22 of Set 14 | riyadh
# Processing Record 23 of Set 14 | cooma
# Processing Record 24 of Set 14 | fraserburgh
# Processing Record 25 of Set 14 | gasa
# Processing Record 26 of Set 14 | ibra
# Processing Record 27 of Set 14 | juifang
# City not found. Skipping...
# Processing Record 28 of Set 14 | mount gambier
# Processing Record 29 of Set 14 | lapeer
# Processing Record 30 of Set 14 | macusani
# Processing Record 31 of Set 14 | bolshoye nagatkino
# Processing Record 32 of Set 14 | boca do acre
# Processing Record 33 of Set 14 | wallenhorst
# Processing Record 34 of Set 14 | kastamonu
# Processing Record 35 of Set 14 | oliva
# Processing Record 36 of Set 14 | makarov
# Processing Record 37 of Set 14 | nanyang
# Processing Record 38 of Set 14 | ta khmau
# Processing Record 39 of Set 14 | ilebo
# Processing Record 40 of Set 14 | nueve de julio
# Processing Record 41 of Set 14 | palora
# Processing Record 42 of Set 14 | presidencia roque saenz pena
# Processing Record 43 of Set 14 | chibuto
# Processing Record 44 of Set 14 | bud
# Processing Record 45 of Set 14 | tirlyanskiy
# Processing Record 46 of Set 14 | liman
# Processing Record 47 of Set 14 | mudgee
# Processing Record 48 of Set 14 | chegem
# Processing Record 49 of Set 14 | biloela
# Processing Record 50 of Set 14 | pecos
# Processing Record 1 of Set 15 | turayf
# Processing Record 2 of Set 15 | bababe
# City not found. Skipping...
# Processing Record 3 of Set 15 | saint-pierre
# Processing Record 4 of Set 15 | paita
# Processing Record 5 of Set 15 | honiara
# Processing Record 6 of Set 15 | kurchum
# Processing Record 7 of Set 15 | kermanshah
# Processing Record 8 of Set 15 | padang
# Processing Record 9 of Set 15 | paralimni
# Processing Record 10 of Set 15 | novyy urengoy
# Processing Record 11 of Set 15 | alta floresta
# Processing Record 12 of Set 15 | soure
# Processing Record 13 of Set 15 | fort nelson
# Processing Record 14 of Set 15 | arrifes
# Processing Record 15 of Set 15 | thunder bay
# Processing Record 16 of Set 15 | severnyy
# Processing Record 17 of Set 15 | maues
# Processing Record 18 of Set 15 | loncoche
# Processing Record 19 of Set 15 | asau
# Processing Record 20 of Set 15 | mogadishu
# Processing Record 21 of Set 15 | cape coast
# Processing Record 22 of Set 15 | saint anthony
# Processing Record 23 of Set 15 | mayo
# Processing Record 24 of Set 15 | aketi
# Processing Record 25 of Set 15 | sorland
# Processing Record 26 of Set 15 | sao desiderio
# Processing Record 27 of Set 15 | coihaique
# Processing Record 28 of Set 15 | mayskiy
# Processing Record 29 of Set 15 | pemberton
# Processing Record 30 of Set 15 | tome-acu
# City not found. Skipping...
# Processing Record 31 of Set 15 | yarqa
# Processing Record 32 of Set 15 | khorol
# Processing Record 33 of Set 15 | dunhua
# Processing Record 34 of Set 15 | fukue
# Processing Record 35 of Set 15 | cabedelo
# Processing Record 36 of Set 15 | sumy
# Processing Record 37 of Set 15 | montbeliard
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Qaanaaq  77.4840  -69.3632    -13.50        86          99
# 1        Hobart -42.8794  147.3294     61.00        63          40
# 2      Ranghulu  46.6500  124.8667     49.17        65           1
# 3          Tura  25.5198   90.2201     69.76        15           0
# 4         Wewak  -3.5534  143.6268     80.51        84         100
# 5     Tuatapere -46.1333  167.6833     60.01        88         100
# 6     Busselton -33.6500  115.3333     63.19        71           0
# 7         Jambi  -1.6000  103.6167     73.85        96          89
# 8     Dongsheng  39.8161  109.9776     32.16        38          50
# 9  Ponta Do Sol  32.6667  -17.1000     64.40        94          75
#
#    Wind Speed Country Current Description
# 0        5.99      GL     overcast clouds
# 1       14.97      AU    scattered clouds
# 2       16.73      CN           clear sky
# 3        2.57      IN           clear sky
# 4        4.23      PG       moderate rain
# 5        5.01      NZ       moderate rain
# 6        7.36      AU           clear sky
# 7        2.21      ID     overcast clouds
# 8       14.58      CN    scattered clouds
# 9       16.11      PT       broken clouds

# %%
clean_city_data_df = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[clean_city_data_df]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Qaanaaq      GL  77.4840  -69.3632    -13.50        86          99
# 1        Hobart      AU -42.8794  147.3294     61.00        63          40
# 2      Ranghulu      CN  46.6500  124.8667     49.17        65           1
# 3          Tura      IN  25.5198   90.2201     69.76        15           0
# 4         Wewak      PG  -3.5534  143.6268     80.51        84         100
# 5     Tuatapere      NZ -46.1333  167.6833     60.01        88         100
# 6     Busselton      AU -33.6500  115.3333     63.19        71           0
# 7         Jambi      ID  -1.6000  103.6167     73.85        96          89
# 8     Dongsheng      CN  39.8161  109.9776     32.16        38          50
# 9  Ponta Do Sol      PT  32.6667  -17.1000     64.40        94          75
#
#    Wind Speed Current Description
# 0        5.99     overcast clouds
# 1       14.97    scattered clouds
# 2       16.73           clear sky
# 3        2.57           clear sky
# 4        4.23       moderate rain
# 5        5.01       moderate rain
# 6        7.36           clear sky
# 7        2.21     overcast clouds
# 8       14.58    scattered clouds
# 9       16.11       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
